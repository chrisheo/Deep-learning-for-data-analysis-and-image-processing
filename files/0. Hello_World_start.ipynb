# %% [markdown]
# #1. TensorFlow 및 Keras

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# Numpy 버전
# Out:
# '1.21.6'

# %%
# TensorFlow 버전
# Out:
# '2.8.2'

# %%
# TF Keras 버전
# Out:
# '2.8.0'

# %% [markdown]
# #2. 파일 업로드

# %% [markdown]
# ## 2.1 일반 업로드

# %% [markdown]
# * 이미지 파일을 업로드하고, python에서 불러오기

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eaa1bd0d-92d2-45a4-be5c-79463b68fc70" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eaa1bd0d-92d2-45a4-be5c-79463b68fc70">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lenna.png to lenna (1).png

# %%
# 이미지 읽어오기
# Out:
# (512, 512, 3)

# %%
# 이미지 모양 보기
# Out:
# 세로 : 512
# 가로 : 512
# 채널 : 3

# %% [markdown]
# 이미지의 가로 1픽셀, 세로 10픽셀을 가져와 봅시다.

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Out:
# (10, 1, 3)

# %%
# Out:
# array([[[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[123, 140, 227]],
#
#        [[119, 134, 228]],
#
#        [[121, 133, 223]],
#
#        [[106, 129, 225]],
#
#        [[104, 130, 223]]], dtype=uint8)

# %%
img[:10, :1].shape
# Out:
# (10, 1, 3)

# %%
img[:10, :1]
# Out:
# array([[[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[123, 140, 227]],
#
#        [[119, 134, 228]],
#
#        [[121, 133, 223]],
#
#        [[106, 129, 225]],
#
#        [[104, 130, 223]]], dtype=uint8)

# %% [markdown]
# 이미지의 뒤쪽 가로 3픽셀, 세로 4픽셀을 가져와 봅시다.

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
# Out:
# (4, 3, 3)

# %%
# Out:
# array([[[122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]]], dtype=uint8)

# %% [markdown]
# 흑백일 경우, 채널이 1이고, 컬러일 경우는 3.

# %%
import cv2

img_gs = cv2.imread("lenna.png", cv2.IMREAD_GRAYSCALE)
img_gs.shape
# Out:
# (512, 512)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Out:
# (10, 1)

# %%
# Out:
# array([[169],
#        [169],
#        [169],
#        [169],
#        [169],
#        [170],
#        [167],
#        [165],
#        [164],
#        [163]], dtype=uint8)

# %%
# Out:
# (10, 1, 3)

# %%
# Out:
# array([[[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[125, 137, 226]],
#
#        [[123, 140, 227]],
#
#        [[119, 134, 228]],
#
#        [[121, 133, 223]],
#
#        [[106, 129, 225]],
#
#        [[104, 130, 223]]], dtype=uint8)

# %% [markdown]
# 컬러 이미지에서는 (10, 1, 3) 모양이었는데, 이번에는 (10, 1) 입니다.
#
# 마지막 채널 차원이 생략되어 있습니다. 컬러 이미지처럼 생각하면, (10, 1, 1) 이겠죠.

# %% [markdown]
# ## 2.2 구글 드라이브 연동

# %% [markdown]
# 1. 코드에서 직접 구글 드라이브 마운트
# 2. 왼쪽의 폴더 아이콘에서 구글 드라이브 아이콘으로 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 구글 드라이브 폴더 이미지 읽기
# Out:
# (512, 512, 3)
