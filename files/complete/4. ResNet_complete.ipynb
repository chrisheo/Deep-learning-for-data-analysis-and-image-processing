# %% [markdown]
# # 사전 준비

# %% [markdown]
# ## 구글 드라이브 마운트

# %% [markdown]
# 1) 왼쪽의 네 개 아이콘 중, 맨 아래 아이콘 클릭해,
#
# 2) Google Drive 아이콘 클릭하여, Google Drive를 마운트합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
base_gdrive_path = 'drive/MyDrive/lecture_220718'

# base_gdrive_path = os.path.join('drive', 'MyDrive', 'lecture_220718')

# %%
from pathlib import Path
import os

result_path = os.path.join(base_gdrive_path, "results")
Path(result_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Imports

# %%
# TensorFlow 및 tf.keras
import tensorflow as tf
from tensorflow import keras

# 도움 라이브러리
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# # CIFAR 100

# %% [markdown]
# ## 데이터 다운 및 분석

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step
# 169017344/169001437 [==============================] - 6s 0us/step

# %%
print("트레이닝 이미지 shape: {}, dtype: {}".format(train_images.shape, train_images.dtype))
print("트레이닝 라벨 shape: {}, dtype: {}".format(train_labels.shape, train_labels.dtype))
# Out:
# 트레이닝 이미지 shape: (50000, 32, 32, 3), dtype: uint8
# 트레이닝 라벨 shape: (50000, 1), dtype: int64

# %%
# 각 숫자의 개수
from collections import Counter
Counter(list(map(lambda el: el[0], train_labels)))
# Out:
# Counter({0: 500,
#          1: 500,
#          2: 500,
#          3: 500,
#          4: 500,
#          5: 500,
#          6: 500,
#          7: 500,
#          8: 500,
#          9: 500,
#          10: 500,
#          11: 500,
#          12: 500,
#          13: 500,
#          14: 500,
#          15: 500,
#          16: 500,
#          17: 500,
#          18: 500,
#          19: 500,
#          20: 500,
#          21: 500,
#          22: 500,
#          23: 500,
#          24: 500,
#          25: 500,
#          26: 500,
#          27: 500,
#          28: 500,
#          29: 500,
#          30: 500,
#          31: 500,
#          32: 500,
#          33: 500,
#          34: 500,
#          35: 500,
#          36: 500,
#          37: 500,
#          38: 500,
#          39: 500,
#          40: 500,
#          41: 500,
#          42: 500,
#          43: 500,
#          44: 500,
#          45: 500,
#          46: 500,
#          47: 500,
#          48: 500,
#          49: 500,
#          50: 500,
#          51: 500,
#          52: 500,
#          53: 500,
#          54: 500,
#          55: 500,
#          56: 500,
#          57: 500,
#          58: 500,
#          59: 500,
#          60: 500,
#          61: 500,
#          62: 500,
#          63: 500,
#          64: 500,
#          65: 500,
#          66: 500,
#          67: 500,
#          68: 500,
#          69: 500,
#          70: 500,
#          71: 500,
#          72: 500,
#          73: 500,
#          74: 500,
#          75: 500,
#          76: 500,
#          77: 500,
#          78: 500,
#          79: 500,
#          80: 500,
#          81: 500,
#          82: 500,
#          83: 500,
#          84: 500,
#          85: 500,
#          86: 500,
#          87: 500,
#          88: 500,
#          89: 500,
#          90: 500,
#          91: 500,
#          92: 500,
#          93: 500,
#          94: 500,
#          95: 500,
#          96: 500,
#          97: 500,
#          98: 500,
#          99: 500})

# %%
print("테스트 이미지 shape: {}, dtype: {}".format(test_images.shape, test_images.dtype))
print("테스트 라벨 shape: {}, dtype: {}".format(test_labels.shape, test_labels.dtype))
# Out:
# 테스트 이미지 shape: (10000, 32, 32, 3), dtype: uint8
# 테스트 라벨 shape: (10000, 1), dtype: int64

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 샘플 데이터 하나 살펴보기

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# 데이터를 비율로 변경. 트레이닝을 더 잘 시키기 위함

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# binary cmap으로 트레이닝 이미지 여러 개 살펴보기

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(train_labels[i])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # ResNet

# %% [markdown]
# ## 모델 (34-layer-residual)

# %%
def resnet_34(input_shape = (224, 224, 3), class_num = 1000):
    base_channel_num = 32  # 64 in paper

    input = keras.layers.Input(input_shape)

    conv_1 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=7, strides=2, padding='same', activation='relu')(input)

    conv_2 = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(conv_1)

    conv_2_residual = conv_2
    conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
    conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
    conv_2 = keras.layers.Add()([conv_2, conv_2_residual])  # 1
    conv_2_residual = conv_2
    conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
    conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
    conv_2 = keras.layers.Add()([conv_2, conv_2_residual])  # 2
    conv_2_residual = conv_2
    conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
    conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
    conv_2 = keras.layers.Add()([conv_2, conv_2_residual])  # 3

    conv_3_residual = conv_2
    conv_3_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(conv_3_residual)
    conv_3_residual = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=1, padding='same', activation='relu')(conv_3_residual)
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, strides=2, padding='same', activation='relu')(conv_2)
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Add()([conv_3, conv_3_residual])  # 1
    conv_3_residual = conv_3
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Add()([conv_3, conv_3_residual])  # 2
    conv_3_residual = conv_3
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Add()([conv_3, conv_3_residual])  # 3
    conv_3_residual = conv_3
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Conv2D(filters=base_channel_num*2, kernel_size=3, padding='same', activation='relu')(conv_3)
    conv_3 = keras.layers.Add()([conv_3, conv_3_residual])  # 4

    conv_4_residual = conv_3
    conv_4_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(conv_4_residual)
    conv_4_residual = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=1, padding='same', activation='relu')(conv_4_residual)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, strides=2, padding='same', activation='relu')(conv_3)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Add()([conv_4, conv_4_residual])  # 1
    conv_4_residual = conv_4
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Add()([conv_4, conv_4_residual])  # 2
    conv_4_residual = conv_4
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Add()([conv_4, conv_4_residual])  # 3
    conv_4_residual = conv_4
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Add()([conv_4, conv_4_residual])  # 4
    conv_4_residual = conv_4
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Add()([conv_4, conv_4_residual])  # 5
    conv_4_residual = conv_4
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Conv2D(filters=base_channel_num*4, kernel_size=3, padding='same', activation='relu')(conv_4)
    conv_4 = keras.layers.Add()([conv_4, conv_4_residual])  # 6
    
    conv_5_residual = conv_4
    conv_5_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(conv_5_residual)
    conv_5_residual = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=1, padding='same', activation='relu')(conv_5_residual)
    conv_5 = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=3, strides=2, padding='same', activation='relu')(conv_4)
    conv_5 = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=3, padding='same', activation='relu')(conv_5)
    conv_5 = keras.layers.Add()([conv_5, conv_5_residual])  # 1
    conv_5_residual = conv_5
    conv_5 = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=3, padding='same', activation='relu')(conv_5)
    conv_5 = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=3, padding='same', activation='relu')(conv_5)
    conv_5 = keras.layers.Add()([conv_5, conv_5_residual])  # 2
    conv_5_residual = conv_5
    conv_5 = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=3, padding='same', activation='relu')(conv_5)
    conv_5 = keras.layers.Conv2D(filters=base_channel_num*8, kernel_size=3, padding='same', activation='relu')(conv_5)
    conv_5 = keras.layers.Add()([conv_5, conv_5_residual])  # 3

    ap = keras.layers.GlobalAveragePooling2D()(conv_5)
    dense_1 = keras.layers.Dense(units=class_num, activation='softmax')(ap)
    
    return keras.models.Model(inputs=[input], outputs=[dense_1])

# %%
model = resnet_34()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  4736        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 32)   9248        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 32)   9248        ['conv2d_1[0][0]']
#
#  add (Add)                      (None, 56, 56, 32)   0           ['conv2d_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 32)   9248        ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   9248        ['conv2d_3[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 32)   0           ['conv2d_4[0][0]',
#                                                                   'add[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 32)   9248        ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   9248        ['conv2d_5[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 32)   0           ['conv2d_6[0][0]',
#                                                                   'add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 64)   18496       ['add_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 32)  0           ['add_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 64)   36928       ['conv2d_8[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 64)   2112        ['max_pooling2d_1[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 64)   0           ['conv2d_9[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 64)   36928       ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_10[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 64)   0           ['conv2d_11[0][0]',
#                                                                   'add_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 64)   36928       ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_12[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 64)   0           ['conv2d_13[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   36928       ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_14[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 64)   0           ['conv2d_15[0][0]',
#                                                                   'add_5[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 128)  73856       ['add_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 64)  0           ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_17[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 128)  8320        ['max_pooling2d_2[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 128)  0           ['conv2d_18[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 128)  147584      ['add_7[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_19[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 128)  0           ['conv2d_20[0][0]',
#                                                                   'add_7[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 128)  147584      ['add_8[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_21[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 128)  0           ['conv2d_22[0][0]',
#                                                                   'add_8[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 128)  147584      ['add_9[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_23[0][0]']
#
#  add_10 (Add)                   (None, 14, 14, 128)  0           ['conv2d_24[0][0]',
#                                                                   'add_9[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 128)  147584      ['add_10[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_25[0][0]']
#
#  add_11 (Add)                   (None, 14, 14, 128)  0           ['conv2d_26[0][0]',
#                                                                   'add_10[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 128)  147584      ['add_11[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_27[0][0]']
#
#  add_12 (Add)                   (None, 14, 14, 128)  0           ['conv2d_28[0][0]',
#                                                                   'add_11[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 256)    295168      ['add_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 128)   0           ['add_12[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 256)    590080      ['conv2d_30[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 256)    33024       ['max_pooling2d_3[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 256)    0           ['conv2d_31[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 256)    590080      ['add_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 256)    590080      ['conv2d_32[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 256)    0           ['conv2d_33[0][0]',
#                                                                   'add_13[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 256)    590080      ['add_14[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 256)    590080      ['conv2d_34[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 256)    0           ['conv2d_35[0][0]',
#                                                                   'add_14[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['add_15[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1000)         257000      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 5,580,520
# Trainable params: 5,580,520
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model = resnet_34(input_shape=(32, 32, 3), class_num=100)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 32)   4736        ['input_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 32)    0           ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 32)     9248        ['max_pooling2d_4[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 32)     9248        ['conv2d_37[0][0]']
#
#  add_16 (Add)                   (None, 8, 8, 32)     0           ['conv2d_38[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 32)     9248        ['add_16[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 32)     9248        ['conv2d_39[0][0]']
#
#  add_17 (Add)                   (None, 8, 8, 32)     0           ['conv2d_40[0][0]',
#                                                                   'add_16[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 32)     9248        ['add_17[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 32)     9248        ['conv2d_41[0][0]']
#
#  add_18 (Add)                   (None, 8, 8, 32)     0           ['conv2d_42[0][0]',
#                                                                   'add_17[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 4, 4, 64)     18496       ['add_18[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 32)    0           ['add_18[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 4, 4, 64)     36928       ['conv2d_44[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 64)     2112        ['max_pooling2d_5[0][0]']
#
#  add_19 (Add)                   (None, 4, 4, 64)     0           ['conv2d_45[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 4, 4, 64)     36928       ['add_19[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 4, 4, 64)     36928       ['conv2d_46[0][0]']
#
#  add_20 (Add)                   (None, 4, 4, 64)     0           ['conv2d_47[0][0]',
#                                                                   'add_19[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 4, 4, 64)     36928       ['add_20[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 4, 4, 64)     36928       ['conv2d_48[0][0]']
#
#  add_21 (Add)                   (None, 4, 4, 64)     0           ['conv2d_49[0][0]',
#                                                                   'add_20[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 4, 4, 64)     36928       ['add_21[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 4, 4, 64)     36928       ['conv2d_50[0][0]']
#
#  add_22 (Add)                   (None, 4, 4, 64)     0           ['conv2d_51[0][0]',
#                                                                   'add_21[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 128)    73856       ['add_22[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 2, 2, 64)    0           ['add_22[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 128)    147584      ['conv2d_53[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 128)    8320        ['max_pooling2d_6[0][0]']
#
#  add_23 (Add)                   (None, 2, 2, 128)    0           ['conv2d_54[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 128)    147584      ['add_23[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 128)    147584      ['conv2d_55[0][0]']
#
#  add_24 (Add)                   (None, 2, 2, 128)    0           ['conv2d_56[0][0]',
#                                                                   'add_23[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 2, 2, 128)    147584      ['add_24[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 2, 2, 128)    147584      ['conv2d_57[0][0]']
#
#  add_25 (Add)                   (None, 2, 2, 128)    0           ['conv2d_58[0][0]',
#                                                                   'add_24[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 2, 2, 128)    147584      ['add_25[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 2, 2, 128)    147584      ['conv2d_59[0][0]']
#
#  add_26 (Add)                   (None, 2, 2, 128)    0           ['conv2d_60[0][0]',
#                                                                   'add_25[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 2, 2, 128)    147584      ['add_26[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 2, 2, 128)    147584      ['conv2d_61[0][0]']
#
#  add_27 (Add)                   (None, 2, 2, 128)    0           ['conv2d_62[0][0]',
#                                                                   'add_26[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 2, 2, 128)    147584      ['add_27[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 2, 2, 128)    147584      ['conv2d_63[0][0]']
#
#  add_28 (Add)                   (None, 2, 2, 128)    0           ['conv2d_64[0][0]',
#                                                                   'add_27[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 1, 1, 256)    295168      ['add_28[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 1, 1, 128)   0           ['add_28[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 1, 1, 256)    590080      ['conv2d_66[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 1, 1, 256)    33024       ['max_pooling2d_7[0][0]']
#
#  add_29 (Add)                   (None, 1, 1, 256)    0           ['conv2d_67[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 1, 1, 256)    590080      ['add_29[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 1, 1, 256)    590080      ['conv2d_68[0][0]']
#
#  add_30 (Add)                   (None, 1, 1, 256)    0           ['conv2d_69[0][0]',
#                                                                   'add_29[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 1, 1, 256)    590080      ['add_30[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 1, 1, 256)    590080      ['conv2d_70[0][0]']
#
#  add_31 (Add)                   (None, 1, 1, 256)    0           ['conv2d_71[0][0]',
#                                                                   'add_30[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['add_31[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 100)          25700       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 5,349,220
# Trainable params: 5,349,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 트레이닝

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])

# %%
history = model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 32s 13ms/step - loss: 4.3675 - sparse_categorical_accuracy: 0.0286
# Epoch 2/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 3.8771 - sparse_categorical_accuracy: 0.0927
# Epoch 3/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 3.5064 - sparse_categorical_accuracy: 0.1551
# Epoch 4/10
# 1563/1563 [==============================] - 21s 14ms/step - loss: 3.2664 - sparse_categorical_accuracy: 0.2001
# Epoch 5/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 3.0937 - sparse_categorical_accuracy: 0.2341
# Epoch 6/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.9564 - sparse_categorical_accuracy: 0.2590
# Epoch 7/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.8447 - sparse_categorical_accuracy: 0.2813
# Epoch 8/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.7488 - sparse_categorical_accuracy: 0.3007
# Epoch 9/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.6530 - sparse_categorical_accuracy: 0.3187
# Epoch 10/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.5723 - sparse_categorical_accuracy: 0.3369

# %% [markdown]
# ## 테스트 및 예측

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('테스트 정확도:', test_acc)
# Out:
# 313/313 - 2s - loss: 2.9536 - sparse_categorical_accuracy: 0.2803 - 2s/epoch - 6ms/step
# 테스트 정확도: 0.28029999136924744

# %% [markdown]
# ### 예측 보기

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)
  
def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(100))
  plt.yticks([])
  thisplot = plt.bar(range(100), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
predictions = model.predict(test_images)

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
test_labels_2 = list(map(lambda el: el[0], test_labels))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels_2, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels_2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 함수로 축약한 모델

# %%
def resnet_34_function_model(input_shape = (224, 224, 3), class_num = 1000):
    base_channel_num = 32  # 64 in paper
    input = keras.layers.Input(input_shape)

    first_layer = resnet_34_1(input=input, base_channel_num=base_channel_num)
    second_layer = resnet_34_2(input=first_layer, base_channel_num=base_channel_num)
    third_layer = resnet_34_3(input=second_layer, base_channel_num=base_channel_num*2)
    fourth_layer = resnet_34_4(input=third_layer, base_channel_num=base_channel_num*4)
    fifth_layer = resnet_34_5(input=fourth_layer, base_channel_num=base_channel_num*8)
    
    ap = keras.layers.GlobalAveragePooling2D()(fifth_layer)
    dense_1 = keras.layers.Dense(units=class_num, activation="softmax")(ap)
    
    return keras.models.Model(inputs=[input], outputs=[dense_1])

def resnet_34_1(input: tf.Tensor, base_channel_num = 64):
    conv_1 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=7, strides=2, padding='same', activation='relu')(input)
    conv_2 = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(conv_1)
    return conv_2 

def resnet_34_2(input: tf.Tensor, base_channel_num = 64):
    result = input
    for i in range(3):
        layer_input_skip = result
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
        conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
        result = conv_2
    return result

def resnet_34_3(input: tf.Tensor, base_channel_num = 64):
    input_residual = input
    input_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(input_residual)
    input_residual = keras.layers.Conv2D(filters=base_channel_num, kernel_size=1, padding="same", activation='relu')(input_residual)
    input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, strides=2, padding="same", activation='relu')(input)
    input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding="same", activation='relu')(input)
    input = keras.layers.Add()([input, input_residual])

    result = input
    for i in range(3):
        layer_input_skip = result
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
        conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
        result = conv_2
    return result

def resnet_34_4(input: tf.Tensor, base_channel_num = 64):
    input_residual = input
    input_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(input_residual)
    input_residual = keras.layers.Conv2D(filters=base_channel_num, kernel_size=1, padding="same", activation='relu')(input_residual)
    input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, strides=2, padding="same", activation='relu')(input)
    input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding="same", activation='relu')(input)
    input = keras.layers.Add()([input, input_residual])

    result = input
    for i in range(5):
        layer_input_skip = result
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
        conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
        result = conv_2
    return result

def resnet_34_5(input: tf.Tensor, base_channel_num = 64):
    input_residual = input
    input_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(input_residual)
    input_residual = keras.layers.Conv2D(filters=base_channel_num, kernel_size=1, padding="same", activation='relu')(input_residual)
    input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, strides=2, padding="same", activation='relu')(input)
    input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding="same", activation='relu')(input)
    input = keras.layers.Add()([input, input_residual])

    result = input
    for i in range(2):
        layer_input_skip = result
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
        conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
        conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
        result = conv_2
    return result

# %%
model_2 = resnet_34_function_model()
model_2.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_72 (Conv2D)             (None, 112, 112, 32  4736        ['input_3[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 56, 56, 32)  0           ['conv2d_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 56, 56, 32)   9248        ['max_pooling2d_8[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 56, 56, 32)   9248        ['conv2d_73[0][0]']
#
#  add_32 (Add)                   (None, 56, 56, 32)   0           ['conv2d_74[0][0]',
#                                                                   'max_pooling2d_8[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 56, 56, 32)   9248        ['add_32[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 56, 56, 32)   9248        ['conv2d_75[0][0]']
#
#  add_33 (Add)                   (None, 56, 56, 32)   0           ['conv2d_76[0][0]',
#                                                                   'add_32[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 56, 56, 32)   9248        ['add_33[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 56, 56, 32)   9248        ['conv2d_77[0][0]']
#
#  add_34 (Add)                   (None, 56, 56, 32)   0           ['conv2d_78[0][0]',
#                                                                   'add_33[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 28, 28, 64)   18496       ['add_34[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 28, 28, 32)  0           ['add_34[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_80[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 28, 28, 64)   2112        ['max_pooling2d_9[0][0]']
#
#  add_35 (Add)                   (None, 28, 28, 64)   0           ['conv2d_81[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 28, 28, 64)   36928       ['add_35[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_82[0][0]']
#
#  add_36 (Add)                   (None, 28, 28, 64)   0           ['conv2d_83[0][0]',
#                                                                   'add_35[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 28, 28, 64)   36928       ['add_36[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_84[0][0]']
#
#  add_37 (Add)                   (None, 28, 28, 64)   0           ['conv2d_85[0][0]',
#                                                                   'add_36[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 28, 28, 64)   36928       ['add_37[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 28, 28, 64)   36928       ['conv2d_86[0][0]']
#
#  add_38 (Add)                   (None, 28, 28, 64)   0           ['conv2d_87[0][0]',
#                                                                   'add_37[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 128)  73856       ['add_38[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 14, 14, 64)  0           ['add_38[0][0]']
#  )
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_89[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 128)  8320        ['max_pooling2d_10[0][0]']
#
#  add_39 (Add)                   (None, 14, 14, 128)  0           ['conv2d_90[0][0]',
#                                                                   'conv2d_88[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 128)  147584      ['add_39[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_91[0][0]']
#
#  add_40 (Add)                   (None, 14, 14, 128)  0           ['conv2d_92[0][0]',
#                                                                   'add_39[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 128)  147584      ['add_40[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_93[0][0]']
#
#  add_41 (Add)                   (None, 14, 14, 128)  0           ['conv2d_94[0][0]',
#                                                                   'add_40[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 14, 14, 128)  147584      ['add_41[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_95[0][0]']
#
#  add_42 (Add)                   (None, 14, 14, 128)  0           ['conv2d_96[0][0]',
#                                                                   'add_41[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 14, 14, 128)  147584      ['add_42[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 14, 14, 128)  147584      ['conv2d_97[0][0]']
#
#  add_43 (Add)                   (None, 14, 14, 128)  0           ['conv2d_98[0][0]',
#                                                                   'add_42[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 14, 14, 128)  147584      ['add_43[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 128)  147584      ['conv2d_99[0][0]']
#
#  add_44 (Add)                   (None, 14, 14, 128)  0           ['conv2d_100[0][0]',
#                                                                   'add_43[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 256)    295168      ['add_44[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 128)   0           ['add_44[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 256)    590080      ['conv2d_102[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 256)    33024       ['max_pooling2d_11[0][0]']
#
#  add_45 (Add)                   (None, 7, 7, 256)    0           ['conv2d_103[0][0]',
#                                                                   'conv2d_101[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 256)    590080      ['add_45[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 256)    590080      ['conv2d_104[0][0]']
#
#  add_46 (Add)                   (None, 7, 7, 256)    0           ['conv2d_105[0][0]',
#                                                                   'add_45[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 256)    590080      ['add_46[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 7, 7, 256)    590080      ['conv2d_106[0][0]']
#
#  add_47 (Add)                   (None, 7, 7, 256)    0           ['conv2d_107[0][0]',
#                                                                   'add_46[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['add_47[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 1000)         257000      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 5,580,520
# Trainable params: 5,580,520
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 커스텀 레이어 사용한 모델

# %%
# def resnet_34_1(input: tf.Tensor, base_channel_num = 64):
#     conv_1 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=7, strides=2, padding='same', activation='relu')(input)
#     conv_2 = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(conv_1)
#     return conv_2 

class ResNetFirstLayer(tf.keras.layers.Layer):
    def __init__(self, channel_num):
        super().__init__()
        self.channel_num = channel_num

        self.conv_1 = keras.layers.Conv2D(filters=channel_num, kernel_size=7, strides=2, padding='same', activation='relu')
        self.conv_2 = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')

    def call(self, inputs):
        x = self.conv_1(inputs)
        x = self.conv_2(x)
        return x

# %%
# def resnet_34_2(input: tf.Tensor, base_channel_num = 64):
#     result = input
#     for i in range(3):
#         layer_input_skip = result
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
#         conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
#         result = conv_2
#     return result
    
class ResNetSecondLayer(tf.keras.layers.Layer):
    def __init__(self, channel_num):
        super().__init__()
        self.channel_num = channel_num

        self.conv_1a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_1b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_2a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_2b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_3a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_3b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')

    def call(self, inputs):
        x_residual = inputs
        x = self.conv_1a(inputs)
        x = self.conv_1b(x)
        x = keras.layers.Add()([inputs, x_residual])
        
        x_residual = x
        x = self.conv_2a(x)
        x = self.conv_2b(x)
        x = keras.layers.Add()([x, x_residual])

        x_residual = x
        x = self.conv_3a(x)
        x = self.conv_3b(x)
        x = keras.layers.Add()([x, x_residual])
        return x

# %%
# def resnet_34_3(input: tf.Tensor, base_channel_num = 64):
#     input_residual = input
#     input_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(input_residual)
#     input_residual = keras.layers.Conv2D(filters=base_channel_num, kernel_size=1, padding="same", activation='relu')(input_residual)
#     input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, strides=2, padding="same", activation='relu')(input)
#     input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding="same", activation='relu')(input)
#     input = keras.layers.Add()([input, input_residual])

#     result = input
#     for i in range(3):
#         layer_input_skip = result
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
#         conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
#         result = conv_2
#     return result
    
class ResNetThirdLayer(tf.keras.layers.Layer):
    def __init__(self, channel_num):
        super().__init__()
        self.channel_num = channel_num

        self.residual_conv = keras.layers.Conv2D(filters=channel_num, kernel_size=1, padding="same", activation='relu')

        self.conv_1a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, strides=2, padding="same", activation='relu')
        self.conv_1b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding="same", activation='relu')

        self.conv_2a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_2b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_3a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_3b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_4a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')
        self.conv_4b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu')

    def call(self, inputs):
        x_residual = inputs
        x_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(x_residual)
        x_residual = self.residual_conv(x_residual)
        x = self.conv_1a(inputs)
        x = self.conv_1b(x)
        x = keras.layers.Add()([x, x_residual])

        x_residual = x
        x = self.conv_2a(x)
        x = self.conv_2b(x)
        x = keras.layers.Add()([x, x_residual])

        x_residual = x
        x = self.conv_3a(x)
        x = self.conv_3b(x)
        x = keras.layers.Add()([x, x_residual])

        x_residual = x
        x = self.conv_4a(x)
        x = self.conv_4b(x)
        x = keras.layers.Add()([x, x_residual])
        return x

# %%
# def resnet_34_4(input: tf.Tensor, base_channel_num = 64):
#     input_residual = input
#     input_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(input_residual)
#     input_residual = keras.layers.Conv2D(filters=base_channel_num, kernel_size=1, padding="same", activation='relu')(input_residual)
#     input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, strides=2, padding="same", activation='relu')(input)
#     input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding="same", activation='relu')(input)
#     input = keras.layers.Add()([input, input_residual])

#     result = input
#     for i in range(5):
#         layer_input_skip = result
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
#         conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
#         result = conv_2
#     return result

class ResNetFourthLayer(tf.keras.layers.Layer):
    def __init__(self, channel_num):
        super().__init__()
        self.channel_num = channel_num

        self.residual_conv = keras.layers.Conv2D(filters=channel_num, kernel_size=1, padding="same", activation='relu')

        self.conv_1a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, strides=2, padding="same", activation='relu')
        self.conv_1b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding="same", activation='relu')

        self.conv_list = [keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu') for i in range(2*5)]

    def call(self, inputs):
        x_residual = inputs
        x_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(x_residual)
        x_residual = self.residual_conv(x_residual)
        x = self.conv_1a(inputs)
        x = self.conv_1b(x)
        x = keras.layers.Add()([x, x_residual])

        for i in range(5):
            x_residual = x
            x = self.conv_list[2*i](x)
            x = self.conv_list[2*i+1](x)
            x = keras.layers.Add()([x, x_residual])
        return x

# %%
# def resnet_34_5(input: tf.Tensor, base_channel_num = 64):
#     input_residual = input
#     input_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(input_residual)
#     input_residual = keras.layers.Conv2D(filters=base_channel_num, kernel_size=1, padding="same", activation='relu')(input_residual)
#     input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, strides=2, padding="same", activation='relu')(input)
#     input = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding="same", activation='relu')(input)
#     input = keras.layers.Add()([input, input_residual])

#     result = input
#     for i in range(2):
#         layer_input_skip = result
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(result)
#         conv_2 = keras.layers.Conv2D(filters=base_channel_num, kernel_size=3, padding='same', activation='relu')(conv_2)
#         conv_2 = keras.layers.Add()([conv_2, layer_input_skip])
#         result = conv_2
#     return result

class ResNetFifthLayer(tf.keras.layers.Layer):
    def __init__(self, channel_num, repeat_num=2):
        super().__init__()
        self.channel_num = channel_num
        self.repeat_num = repeat_num

        self.residual_conv = keras.layers.Conv2D(filters=channel_num, kernel_size=1, padding="same", activation='relu')

        self.conv_1a = keras.layers.Conv2D(filters=channel_num, kernel_size=3, strides=2, padding="same", activation='relu')
        self.conv_1b = keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding="same", activation='relu')

        self.conv_list = [keras.layers.Conv2D(filters=channel_num, kernel_size=3, padding='same', activation='relu') for i in range(2*self.repeat_num)]

    def call(self, inputs):
        x_residual = inputs
        x_residual = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(x_residual)
        x_residual = self.residual_conv(x_residual)
        x = self.conv_1a(inputs)
        x = self.conv_1b(x)
        x = keras.layers.Add()([x, x_residual])

        for i in range(self.repeat_num):
            x_residual = x
            x = self.conv_list[2*i](x)
            x = self.conv_list[2*i+1](x)
            x = keras.layers.Add()([x, x_residual])
        return x

# %%
def resnet_34_custom_layer_model(input_shape = (224, 224, 3), class_num = 1000):
    base_channel_num = 32  # 64 in paper
    input = keras.layers.Input(input_shape)

    first = ResNetFirstLayer(channel_num=base_channel_num)(input)
    second = ResNetSecondLayer(channel_num=base_channel_num)(first)
    third = ResNetThirdLayer(channel_num=base_channel_num*2)(second)
    fourth = ResNetFourthLayer(channel_num=base_channel_num*4)(third)
    fifth = ResNetFifthLayer(channel_num=base_channel_num*8)(fourth)
    
    ap = keras.layers.GlobalAveragePooling2D()(fifth)
    dense_1 = keras.layers.Dense(units=class_num, activation="softmax")(ap)
    
    return keras.models.Model(inputs=[input], outputs=[dense_1])

# %%
model_3 = resnet_34_custom_layer_model()
model_3.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  res_net_first_layer (ResNet  (None, 56, 56, 32)       4736
#  FirstLayer)
#
#  res_net_second_layer (ResNe  (None, 56, 56, 32)       55488
#  tSecondLayer)
#
#  res_net_third_layer (ResNet  (None, 28, 28, 64)       279104
#  ThirdLayer)
#
#  res_net_fourth_layer (ResNe  (None, 14, 14, 128)      1705600
#  tFourthLayer)
#
#  res_net_fifth_layer (ResNet  (None, 7, 7, 256)        3278592
#  FifthLayer)
#
#  global_average_pooling2d_3   (None, 256)              0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 1000)              257000
#
# =================================================================
# Total params: 5,580,520
# Trainable params: 5,580,520
# Non-trainable params: 0
# _________________________________________________________________

# %%
def resnet_34_custom_layer_model_2(input_shape = (224, 224, 3), class_num = 1000):
    base_channel_num = 32  # 64 in paper
    input = keras.layers.Input(input_shape)

    first = ResNetFirstLayer(channel_num=base_channel_num)(input)
    second = ResNetSecondLayer(channel_num=base_channel_num)(first)
    third = ResNetFifthLayer(channel_num=base_channel_num*2, repeat_num=3)(second)
    fourth = ResNetFifthLayer(channel_num=base_channel_num*4, repeat_num=5)(third)
    fifth = ResNetFifthLayer(channel_num=base_channel_num*8, repeat_num=2)(fourth)
    
    ap = keras.layers.GlobalAveragePooling2D()(fifth)
    dense_1 = keras.layers.Dense(units=class_num, activation="softmax")(ap)
    
    return keras.models.Model(inputs=[input], outputs=[dense_1])

# %%
model_4 = resnet_34_custom_layer_model_2()
model_4.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  res_net_first_layer_1 (ResN  (None, 56, 56, 32)       4736
#  etFirstLayer)
#
#  res_net_second_layer_1 (Res  (None, 56, 56, 32)       55488
#  NetSecondLayer)
#
#  res_net_fifth_layer_1 (ResN  (None, 28, 28, 64)       279104
#  etFifthLayer)
#
#  res_net_fifth_layer_2 (ResN  (None, 14, 14, 128)      1705600
#  etFifthLayer)
#
#  res_net_fifth_layer_3 (ResN  (None, 7, 7, 256)        3278592
#  etFifthLayer)
#
#  global_average_pooling2d_4   (None, 256)              0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 1000)              257000
#
# =================================================================
# Total params: 5,580,520
# Trainable params: 5,580,520
# Non-trainable params: 0
# _________________________________________________________________
